# %% [markdown]
# ## LGMVIP Internship- Let's Grow More
# ### Data Science Internship task(Prediction Using Decision Tree Algorithm)

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
#Loading Dataset
df=pd.read_csv('Iris.csv')

# %%
 df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Finding null values
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]>

# %%
df=df.drop(columns=['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# data description
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# ### Data Visualization

# %%
colors=['green','orange','blue']
species=['Iris-viriginca','Iris-versicolor','Iris-setosa']

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.axis('equal')
l=['Versicolor','Setosa','Virginica']
s=[50,50,50]
ax.pie(s,labels=l,autopct='%1.2f%%')
plt.show()

# %%
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'],c=colors[i],label=species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'],c=colors[i],label=species[i])
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalLengthCm'],c=colors[i],label=species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Species']=le.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns=['Species'])
Y=df['Species']
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30)

# %% [markdown]
# ### Model Building Decision Tree :

# %%
clf=DecisionTreeClassifier()
clf=clf.fit(x_train,y_train)
clf
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([1, 0, 1, 0, 0, 0, 0, 0, 1, 2, 2, 1, 1, 1, 1, 2, 0, 0, 2, 0, 0, 0,
#        1, 0, 0, 0, 1, 0, 1, 1, 0, 1, 0, 0, 0, 1, 2, 2, 2, 1, 0, 0, 0, 2,
#        2])

# %%
data_frame =pd.DataFrame({'Actual Data':y_test,"Predicted Data":y_pred})
data_frame.head()
# Out:
#     Actual Data  Predicted Data
# 74            1               1
# 31            0               0
# 65            1               1
# 21            0               0
# 39            0               0

# %% [markdown]
# ### Accuracy of the model:

# %%
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.9555555555555556

# %% [markdown]
# ### Visualizing the decision tree:

# %%
col_names = ["Sepal length","Sepal width","Petal length","Petal width"]
target_names=["Setosa","Versicolor","Virginica"]

# %%
plot_tree(clf,feature_names=col_names,class_names=target_names,filled=True)
# Out:
# [Text(167.40000000000003, 195.696, 'Petal length <= 4.85\ngini = 0.659\nsamples = 105\nvalue = [28, 36, 41]\nclass = Virginica'),
#  Text(66.96000000000001, 152.208, 'Petal length <= 2.45\ngini = 0.525\nsamples = 64\nvalue = [28, 34, 2]\nclass = Versicolor'),
#  Text(33.480000000000004, 108.72, 'gini = 0.0\nsamples = 28\nvalue = [28, 0, 0]\nclass = Setosa'),
#  Text(100.44000000000001, 108.72, 'Petal width <= 1.65\ngini = 0.105\nsamples = 36\nvalue = [0, 34, 2]\nclass = Versicolor'),
#  Text(66.96000000000001, 65.232, 'gini = 0.0\nsamples = 33\nvalue = [0, 33, 0]\nclass = Versicolor'),
#  Text(133.92000000000002, 65.232, 'Sepal width <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = Virginica'),
#  Text(100.44000000000001, 21.744, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Virginica'),
#  Text(167.40000000000003, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(267.84000000000003, 152.208, 'Petal width <= 1.75\ngini = 0.093\nsamples = 41\nvalue = [0, 2, 39]\nclass = Virginica'),
#  Text(234.36, 108.72, 'Sepal length <= 6.2\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]\nclass = Virginica'),
#  Text(200.88000000000002, 65.232, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Virginica'),
#  Text(267.84000000000003, 65.232, 'Petal length <= 5.4\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = Versicolor'),
#  Text(234.36, 21.744, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = Versicolor'),
#  Text(301.32000000000005, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(301.32000000000005, 108.72, 'gini = 0.0\nsamples = 36\nvalue = [0, 0, 36]\nclass = Virginica')]

# %%
model=DecisionTreeClassifier().fit(X,Y)

# %%
plt.figure(figsize=(20,15))
tree=tree.plot_tree(model,feature_names=col_names,class_names=target_names,filled=True)
